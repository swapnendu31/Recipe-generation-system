# %%
import pyforest

# %%
df = pd.read_csv('recipe_dataste/modified_recipes_dataset.csv')
df
# Out:
#        Srno                                         RecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2              - Spicy Tomato Rice (Recipe In Hindi)
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5                  - Adrak Chutney (Recipe In Hindi)
# ...     ...                                                ...
# 6860  14073                      - Goan Mushroom Xacuti Recipe
# 6861  14107      - Sweet Potato & Methi Stuffed Paratha Recipe
# 6862  14165      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6863  14167  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 6864  14211                               - Navrang Dal Recipe
#
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# ...

# %%
import pandas as pd
import re

# Sample DataFrame for demonstration (replace this with your actual DataFrame)
# df4_tran = pd.DataFrame({'Ingredients': [...]}) # Your DataFrame

# Set to store unique words
unique_words = set()

# Function to extract unique words from ingredients
def extract_unique_words(ingredients):
    # Split the ingredients into words
    words = re.findall(r'\b\w+\b', ingredients)  # Extract words using regex
    for word in words:
        # Check if the word is not a number (int or float)
        if not re.match(r'^\d+\.?\d*$', word):  # Match whole numbers or decimals
            unique_words.add(word.lower())  # Add the word in lowercase to ensure uniqueness

# Iterate over each row in the Ingredients column
for ingredients in df['Ingredients']:
    extract_unique_words(str(ingredients))  # Convert to string to handle NaN values

# Convert the set to a list
unique_words_list = list(unique_words)

# Print the unique words
print("Unique words in the Ingredients column:", unique_words_list)
# Out:
# Unique words in the Ingredients column: ['top', 'रद', 'kadam', 'pabda', 'raw', 'kakoda', 'gooseberries', 'durum', 'chhedar', 'kale', 'roun', 'herring', 'preferably', 'bud', 'strawberry', 'desired', 'deeseeded', 'vazhaipoo', 'chai', 'crepe', 'nuts', 'fennel', 'tightened', 'strand', 'gram', 'pistachi', 'junks', 'taco', 'candies', 'salsa', 'jerk', 'pacha', 'button', 'biscuits', 'eat', 'twig', 'clamps', 'घ', 'breadcrumbarb', 'saved', 'inches', 'colored', 'social', 'browned', 'cupssemolina', 'spice', 'liquid', 'papads', 'layers', 'choppedle', 'gobbi', 'lemons', 'अरब', 'achar', 'raspberry', 'sichuan', 'bru', 'evenly', 'smear', 'broke', 'iron', 'lumps', 'inchlentil', 'round2', 'compute', 'clotted', 'nescafé', 'number', 'burger', 'chenna', 'barrel', 'side', 'vegetables', 'monte', 'moggu', 'granules', 'frutti', 'lima', 'tahini', 'pointed', 'pink', 'wraps', 'tightentake', 'early', 'chillas', 'blueberry', 'teaspoonmole', 'magaz', 'valrhona', '2socke', 'aam', 'tur', 'belly', 'germ', 'compound', 
# ...

# %%
a = df['Ingredients']
a[55]
# Out:
# '250 grams Fish fillet - basa,250 grams Prawns,15 Clamps,5 Baby Potatoes,2 Carrots (Gajjar),1 Onion,1 Tomato,2 Fresh Red chillies,5 cloves Garlic,1 teaspoon Cumin powder (Jeera),2 teaspoon Paprika powder,Salt - to taste,1 tablespoon Lemon juice,1 teaspoon Black pepper powder,4 tablespoon Coriander (Dhania) Leaves,1 tablespoon Extra Virgin Olive Oil,1 cup Chicken stock,1/4 cup Coconut milk'

# %%
import re

# Function to check if a string contains Hindi characters
def contains_hindi(text):
    hindi_chars = re.compile(r'[\u0900-\u097F]+')  # Unicode range for Hindi characters
    return bool(hindi_chars.search(text))

# Get the indices of rows where Ingredients contain Hindi
hindi_indices = df[df['Ingredients'].apply(lambda x: contains_hindi(str(x)))].index.tolist()

# Print the indices
print("Indices of rows with Hindi ingredients:", hindi_indices)
# Out:
# Indices of rows with Hindi ingredients: [380, 2768, 3355, 4017, 4332, 4771, 4962, 5023, 5269, 5354, 5800, 6221, 6225, 6588, 6619, 6776, 6819]

# %%
import re

# Function to check if a string contains Hindi characters
def contains_hindi(text):
    hindi_chars = re.compile(r'[\u0900-\u097F]+')  # Unicode range for Hindi characters
    return bool(hindi_chars.search(text))

# Get the indices of rows where Ingredients contain Hindi
hindi_indices = df[df['Ingredients'].apply(lambda x: contains_hindi(str(x)))].index

# Drop the rows with Hindi ingredients
df.drop(hindi_indices, inplace=True)

# Reset the index of the DataFrame (optional)
df.reset_index(drop=True, inplace=True)

# Print the updated DataFrame
print("Updated DataFrame after removing rows with Hindi ingredients:")
print(df)
# Out:
# Updated DataFrame after removing rows with Hindi ingredients:
#        Srno                                         RecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2              - Spicy Tomato Rice (Recipe In Hindi)
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5                  - Adrak Chutney (Recipe In Hindi)
# ...     ...                                                ...
# 6843  14073                      - Goan Mushroom Xacuti Recipe
# 6844  14107      - Sweet Potato & Methi Stuffed Paratha Recipe
# 6845  14165      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6846  14167  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 6847  14211                               - Navrang Dal Recipe
#
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# ...

# %%
import re

# Function to check if a string contains Hindi characters
def contains_hindi(text):
    hindi_chars = re.compile(r'[\u0900-\u097F]+')  # Unicode range for Hindi characters
    return bool(hindi_chars.search(text))

# Get the indices of rows where Ingredients contain Hindi
hindi_indices = df[df['Ingredients'].apply(lambda x: contains_hindi(str(x)))].index.tolist()

# Print the indices
print("Indices of rows with Hindi ingredients:", hindi_indices)
# Out:
# Indices of rows with Hindi ingredients: []

# %%
import pandas as pd
import re

# Sample DataFrame for demonstration (replace this with your actual DataFrame)
# df4_tran = pd.DataFrame({'Ingredients': [...]}) # Your DataFrame

# Set to store unique words
unique_words = set()

# Function to extract unique words from ingredients
def extract_unique_words(ingredients):
    # Split the ingredients into words
    words = re.findall(r'\b\w+\b', ingredients)  # Extract words using regex
    for word in words:
        # Check if the word is not a number (int or float)
        if not re.match(r'^\d+\.?\d*$', word):  # Match whole numbers or decimals
            unique_words.add(word.lower())  # Add the word in lowercase to ensure uniqueness

# Iterate over each row in the Ingredients column
for ingredients in df['Ingredients']:
    extract_unique_words(str(ingredients))  # Convert to string to handle NaN values

# Convert the set to a list
unique_words_list = list(unique_words)

# Print the unique words
print("Unique words in the Ingredients column:", unique_words_list)
# Out:
# Unique words in the Ingredients column: ['top', 'kadam', 'pabda', 'raw', 'kakoda', 'gooseberries', 'durum', 'chhedar', 'kale', 'roun', 'herring', 'preferably', 'bud', 'strawberry', 'desired', 'deeseeded', 'vazhaipoo', 'chai', 'crepe', 'nuts', 'fennel', 'tightened', 'strand', 'gram', 'pistachi', 'junks', 'taco', 'candies', 'salsa', 'jerk', 'pacha', 'button', 'biscuits', 'eat', 'twig', 'clamps', 'breadcrumbarb', 'saved', 'inches', 'colored', 'social', 'browned', 'cupssemolina', 'spice', 'liquid', 'papads', 'layers', 'choppedle', 'gobbi', 'lemons', 'achar', 'raspberry', 'sichuan', 'bru', 'evenly', 'smear', 'broke', 'iron', 'lumps', 'inchlentil', 'round2', 'compute', 'clotted', 'nescafé', 'number', 'burger', 'chenna', 'barrel', 'side', 'vegetables', 'monte', 'moggu', 'granules', 'frutti', 'lima', 'tahini', 'pointed', 'pink', 'wraps', 'tightentake', 'early', 'chillas', 'blueberry', 'teaspoonmole', 'magaz', 'valrhona', '2socke', 'aam', 'tur', 'belly', 'germ', 'compound', 'chilli', 'besan',
# ...

# %%
df.head(3)
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2              - Spicy Tomato Rice (Recipe In Hindi)
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
#
#                                          Ingredients  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...
# 1  2-1/2 cup rice - cook, 3 tomatoes, 3 teaspoons...
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...
#
#                                TranslatedIngredients  PrepTimeInMins  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...              15
# 1  2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...               5
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...              20
#
# ...

# %%
vegetable_array =[
  'amaranth', 'amaranth leaves', 'amaranth leavess', 'apple gourd', 'apple gourds', 'arugula', 'ash gourd', 
  'ash gourds', 'asparagus', 'asparaguses', 'baby corn', 'bamboo shoot', 'bamboo shoots', 'bean', 'beans', 
  'beetroot', 'beetroots', 'bitter gourd', 'bitter gourds', 'bottle gourd', 'bottle gourds', 'brinjal', 
  'brinjals', 'broccoli', 'broccolis', 'cabbage', 'cabbages', 'capsicum', 'capsicums', 'cape gooseberry', 
  'carrot', 'carrots', 'cassava', 'celeries', 'celery', 'chickpea', 'chives', 'cluster bean', 'cluster beans', 
  'coconut', 'coconuts', 'colocasia root', 'colocasia leave', 'coriander leaf', 'coriander leaves', 
  'coriander leavess', 'cress', 'cresses', 'cucumber', 'cucumbers', 'curry leaf', 'curry leaves', 'curry leafss', 
  'dill', 'dill leaves', 'dill leavess', 'drumstick', 'drumsticks', 'drumstickss', 'elephant foot yam', 'endive', 
  'endives', 'fava bean', 'fava beans', 'fenugreek leaf', 'fenugreek leaves', 'fenugreek leavess', 'french bean', 
  'french beans', 'garlic', 'garlic chives', 'garlics', 'ginger', 'gingers', 'gooseberry', 'gooseberries', 
  'green chili', 'green chili peppers', 'green onion', 'ivy gourd', 'ivy gourds', 'jackfruit', 'jackfruits', 
  'jute flower', 'kale', 'kales', 'kidney bean', 'kidney beans', 'lady finger', 'ladies finger', 'ladies fingers', 
  'lemon', 'lemons', 'lettuce', 'lettuce leaves', 'lettuce leavess', 'little gourd', 'little gourds', 'lotus root', 
  'mints', 'mushroom', 'mushrooms', 'mustard green', 'mustard greens', 'mustard leaves', 'natal plum', 'olive', 
  'onion', 'onions', 'parsnip', 'parsnips', 'pea', 'peas', 'plantain', 'plantains', 'pointed gourd', 
  'pointed gourds', 'potato', 'potatoes', 'pumpkin', 'pumpkins', 'radish', 'radishes', 'raw banana flower', 
  'raw mango', 'raw mangoes', 'raw papaya', 'red chili', 'rhubarb', 'rhubarbs', 'ridge gourd', 'ridge gourds', 
  'runner beans', 'scallions', 'shallot', 'shallots', 'snake gourd', 'snake gourds', 'soya bean', 'soya beans', 
  'spinach', 'spine gourd', 'spiny gourd', 'spiny gourds', 'spring onion', 'spring onions', 'sponge gourd', 
  'sponge gourds', 'sweet corn', 'sweet corns', 'sweet potato', 'sweet potatoes', 'tamarind', 'tamarinds', 
  'taro', 'taro root', 'taros', 'tendli gourd', 'tomato', 'tomatoes', 'turnip', 'turnips', 'water chestnut', 
  'water chestnuts', 'white brinjal', 'wild spinach', 'yam', 'yams'
]

# %%
# Dictionary mapping plural forms to singular forms
plural_to_singular = {
    'amaranth leaves': 'amaranth leaf', 
    'amaranth leavess': 'amaranth leaf',
    'apple gourds': 'apple gourd',
    'ash gourds': 'ash gourd',
    'asparaguses': 'asparagus',
    'bamboo shoots': 'bamboo shoot',
    'beans': 'bean',
    'beetroots': 'beetroot',
    'bitter gourds': 'bitter gourd',
    'bottle gourds': 'bottle gourd',
    'brinjals': 'brinjal',
    'broccolis': 'broccoli',
    'cabbages': 'cabbage',
    'capsicums': 'capsicum',
    'carrots': 'carrot',
    'cassavas': 'cassava',
    'celeries': 'celery',
    'chickpeas': 'chickpea',
    'chives': 'chive',
    'cluster beans': 'cluster bean',
    'coconuts': 'coconut',
    'colocasia ': 'colocasia leaf',
    'coriander leaves': 'coriander leaf',
    'coriander leavess': 'coriander leaf',
    'cresses': 'cress',
    'cucumbers': 'cucumber',
    'curry leaves': 'curry leaf',
    'curry leafss': 'curry leaf',
    'dill leaves': 'dill',
    'dill leavess': 'dill',
    'drumsticks': 'drumstick',
    'drumstickss': 'drumstick',
    'endives': 'endive',
    'fava beans': 'fava bean',
    'fenugreek leaves': 'fenugreek leaf',
    'fenugreek leavess': 'fenugreek leaf',
    'french beans': 'french bean',
    'garlics': 'garlic',
    'gingers': 'ginger',
    'gooseberries': 'gooseberry',
    'green chili peppers': 'green chili',
    'ivy gourds': 'ivy gourd',
    'jackfruits': 'jackfruit',
    'kales': 'kale',
    'kidney beans': 'kidney bean',
    'ladies fingers': 'lady finger',
    'lemons': 'lemon',
    'lettuce leaves': 'lettuce leaf',
    'lettuce leavess': 'lettuce leaf',
    'little gourds': 'little gourd',
    'mints': 'mint',
    'mushrooms': 'mushroom',
    'mustard greens': 'mustard green',
    'mustard leaves': 'mustard leaf',
    'onions': 'onion',
    'parsnips': 'parsnip',
    'peas': 'pea',
    'plantains': 'plantain',
    'pointed gourds': 'pointed gourd',
    'potatoes': 'potato',
    'pumpkins': 'pumpkin',
    'radishes': 'radish',
    'raw mangoes': 'raw mango',
    'ridge gourds': 'ridge gourd',
    'runner beans': 'runner bean',
    'shallots': 'shallot',
    'snake gourds': 'snake gourd',
    'soya beans': 'soya bean',
    'spine gourds': 'spine gourd',
    'spiny gourds': 'spiny gourd',
    'spring onions': 'spring onion',
    'sponge gourds': 'sponge gourd',
    'sweet corns': 'sweet corn',
    'sweet potatoes': 'sweet potato',
    'tamarinds': 'tamarind',
    'taros': 'colocasia root',
    'taro' : 'colocasia root',
    'taro root' : 'colocasia root',
    'tendli gourds': 'tendli gourd',
    'tomatoes': 'tomato',
    'turnips': 'turnip',
    'water chestnuts': 'water chestnut',
    'wild spinaches': 'wild spinach',
    'yams': 'yam'
}

def extract_vegetables(ingredient_string):
    # Convert the ingredient string to lowercase before matching
    ingredient_string = ingredient_string.lower()
    
    found_vegetables = []
    
    for veg in vegetable_array:
        # Convert plural to singular if it's in the dictionary
        singular_veg = plural_to_singular.get(veg, veg)
        
        # Check if the vegetable or its plural form is in the ingredient string
        if singular_veg not in found_vegetables and (veg in ingredient_string or singular_veg in ingredient_string):
            found_vegetables.append(singular_veg)
    
    return ",".join(found_vegetables)

# Create a new column with the extracted vegetables
df['Vegetables'] = df['Ingredients'].apply(extract_vegetables)
df
# Out:
#        Srno                                         RecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2              - Spicy Tomato Rice (Recipe In Hindi)
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5                  - Adrak Chutney (Recipe In Hindi)
# ...     ...                                                ...
# 6843  14073                      - Goan Mushroom Xacuti Recipe
# 6844  14107      - Sweet Potato & Methi Stuffed Paratha Recipe
# 6845  14165      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6846  14167  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 6847  14211                               - Navrang Dal Recipe
#
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# ...

# %%
df
# Out:
#        Srno                                         RecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2              - Spicy Tomato Rice (Recipe In Hindi)
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5                  - Adrak Chutney (Recipe In Hindi)
# ...     ...                                                ...
# 6843  14073                      - Goan Mushroom Xacuti Recipe
# 6844  14107      - Sweet Potato & Methi Stuffed Paratha Recipe
# 6845  14165      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6846  14167  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 6847  14211                               - Navrang Dal Recipe
#
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# ...

# %%
df['Vegetables'].isnull().sum()
# Out:
# 0

# %%
df.dropna()
# Out:
#        Srno                                         RecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2              - Spicy Tomato Rice (Recipe In Hindi)
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5                  - Adrak Chutney (Recipe In Hindi)
# ...     ...                                                ...
# 6843  14073                      - Goan Mushroom Xacuti Recipe
# 6844  14107      - Sweet Potato & Methi Stuffed Paratha Recipe
# 6845  14165      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6846  14167  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 6847  14211                               - Navrang Dal Recipe
#
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# ...

# %%
df['Vegetables'].isnull().sum()
# Out:
# 0

# %%
df.to_csv('update_indian.csv',index=False)
